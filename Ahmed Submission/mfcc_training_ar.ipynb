# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Only errors are logged
os.environ['TF_GPU_ALLOCATOR'] ='cuda_malloc_async'

import numpy as np
import keras
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import layers
from keras import ops

# TF imports related to tf.data preprocessing
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow.keras.utils import plot_model

keras.utils.set_random_seed(42)
from sklearn.model_selection import train_test_split
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777486959.408785  905640 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777486960.497672  905640 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
BATCH_SIZE = 32
NUM_CLASSES = 8
EPOCHS = 500
SAMPLE_RATE = 16000
OUT_SEQ_LEN = 72000

# %%
keras.backend.clear_session(free_memory=True)
train_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_mfcc_img_ar/train',
image_size=(300, 300),
batch_size=BATCH_SIZE)
val_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_mfcc_img_ar/val',
image_size=(300, 300),
batch_size=BATCH_SIZE)
test_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_mfcc_img_ar/test',
image_size=(300, 300),
batch_size=BATCH_SIZE)
# Out:
# Found 882 files belonging to 4 classes.
# Found 75 files belonging to 4 classes.
# Found 75 files belonging to 4 classes.

# %%
incv3 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3))
incv3.trainable = False
for layer in incv3.layers[-20:]:
    layer.trainable = True
model_ar = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),
  layers.Rescaling(1./127.5, offset=-1),
  incv3,
  layers.GlobalAveragePooling2D(),
  layers.BatchNormalization(),
  layers.Dense((128),activation='gelu',
                   kernel_regularizer=keras.regularizers.L1L2(l1=1e-5, l2=1e-4),

               ),
  layers.Dropout(0.4),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model_ar.summary()
keras.backend.clear_session(free_memory=True)
model_ar.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-5,weight_decay=1e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,074,280 (84.21 MB)
#  Trainable params: 2,202,760 (8.40 MB)
#  Non-trainable params: 19,871,520 (75.80 MB)

# %%
history_ar = model_ar.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 33s 674ms/step - loss: 2.8038 - sparse_categorical_accuracy: 0.1678 - val_loss: 2.0802 - val_sparse_categorical_accuracy: 0.3333
# Epoch 2/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.4132 - sparse_categorical_accuracy: 0.2551 - val_loss: 2.0470 - val_sparse_categorical_accuracy: 0.4000
# Epoch 3/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.1781 - sparse_categorical_accuracy: 0.3186 - val_loss: 2.0043 - val_sparse_categorical_accuracy: 0.4267
# Epoch 4/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.9914 - sparse_categorical_accuracy: 0.3662 - val_loss: 1.9601 - val_sparse_categorical_accuracy: 0.4533
# Epoch 5/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.8313 - sparse_categorical_accuracy: 0.4184 - val_loss: 1.9067 - val_sparse_categorical_accuracy: 0.4267
# Epoch 6/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.7476 - sparse_categorical_accuracy: 0.4331 - val_loss: 1.8597 - val_sparse_categorical_accuracy: 0.4400
# Epoch 7/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.6132 - sparse_categorical_accuracy: 0.4592 - val_loss: 1.8283 - val_sparse_categorical_accuracy: 0.4400
# Epoch 8/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.5954 - sparse_categorical_accuracy: 0.4694 - val_loss: 1.7893 - val_sparse_categorical_accuracy: 0.4133
# Epoch 9/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.5185 - sparse_categorical_accuracy: 0.5159 - val_loss: 1.7620 - val_sparse_categorical_accuracy: 0.4000
# Epoch 10/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.4832 - sparse_categorical_accuracy: 0.4966 - val_loss: 1.7374 - val_sparse_categorical_accuracy: 0.4000
# Epoch 11/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.4225 - sparse_categorical_accuracy: 0.5420 - val_loss: 1.7155 - val_sparse_categorical_accuracy: 0.4000
# Epoch 12/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.3275 - sparse_categorical_accuracy: 0.5737 - val_loss: 1.7012 - val_sparse_categorical_accuracy: 0.4133
# Epoch 13/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2771 - sparse_categorical_accuracy: 0.5907 - val_loss: 1.7037 - val_sparse_categorical_accuracy: 0.4133
# Epoch 14/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2287 - sparse_categorical_accuracy: 0.5907 - val_loss: 1.7030 - val_sparse_categorical_accuracy: 0.4000
# Epoch 15/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.1353 - sparse_categorical_accuracy: 0.6190 - val_loss: 1.6797 - val_sparse_categorical_accuracy: 0.4133
# Epoch 16/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.1560 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.6872 - val_sparse_categorical_accuracy: 0.4400
# Epoch 17/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.1168 - sparse_categorical_accuracy: 0.6338 - val_loss: 1.6585 - val_sparse_categorical_accuracy: 0.4133
# Epoch 18/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.0795 - sparse_categorical_accuracy: 0.6463 - val_loss: 1.6509 - val_sparse_categorical_accuracy: 0.4400
# Epoch 19/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.0096 - sparse_categorical_accuracy: 0.6757 - val_loss: 1.6461 - val_sparse_categorical_accuracy: 0.4533
# Epoch 20/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0011 - sparse_categorical_accuracy: 0.6746 - val_loss: 1.6516 - val_sparse_categorical_accuracy: 0.4400
# Epoch 21/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.9715 - sparse_categorical_accuracy: 0.6859 - val_loss: 1.6463 - val_sparse_categorical_accuracy: 0.4533
# Epoch 22/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.9665 - sparse_categorical_accuracy: 0.6882 - val_loss: 1.6322 - val_sparse_categorical_accuracy: 0.4533
# Epoch 23/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.9289 - sparse_categorical_accuracy: 0.7029 - val_loss: 1.6297 - val_sparse_categorical_accuracy: 0.4400
# Epoch 24/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.7358 - val_loss: 1.6185 - val_sparse_categorical_accuracy: 0.4533
# Epoch 25/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.8751 - sparse_categorical_accuracy: 0.7324 - val_loss: 1.6140 - val_sparse_categorical_accuracy: 0.4400
# Epoch 26/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.8804 - sparse_categorical_accuracy: 0.7279 - val_loss: 1.6069 - val_sparse_categorical_accuracy: 0.4667
# Epoch 27/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.8283 - sparse_categorical_accuracy: 0.7506 - val_loss: 1.5825 - val_sparse_categorical_accuracy: 0.4533
# Epoch 28/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8142 - sparse_categorical_accuracy: 0.7426 - val_loss: 1.5866 - val_sparse_categorical_accuracy: 0.4533
# Epoch 29/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.8079 - sparse_categorical_accuracy: 0.7404 - val_loss: 1.5966 - val_sparse_categorical_accuracy: 0.4533
# Epoch 30/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7576 - sparse_categorical_accuracy: 0.7789 - val_loss: 1.5803 - val_sparse_categorical_accuracy: 0.4400
# Epoch 31/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7531 - sparse_categorical_accuracy: 0.7653 - val_loss: 1.5719 - val_sparse_categorical_accuracy: 0.4400
# Epoch 32/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7535 - sparse_categorical_accuracy: 0.7653 - val_loss: 1.5685 - val_sparse_categorical_accuracy: 0.4267
# Epoch 33/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7515 - sparse_categorical_accuracy: 0.7800 - val_loss: 1.5460 - val_sparse_categorical_accuracy: 0.4400
# Epoch 34/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7226 - sparse_categorical_accuracy: 0.7971 - val_loss: 1.5428 - val_sparse_categorical_accuracy: 0.4133
# Epoch 35/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6985 - sparse_categorical_accuracy: 0.7891 - val_loss: 1.5457 - val_sparse_categorical_accuracy: 0.4267
# Epoch 36/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6880 - sparse_categorical_accuracy: 0.8061 - val_loss: 1.5432 - val_sparse_categorical_accuracy: 0.4533
# Epoch 37/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.6307 - sparse_categorical_accuracy: 0.8333 - val_loss: 1.5399 - val_sparse_categorical_accuracy: 0.4400
# Epoch 38/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6766 - sparse_categorical_accuracy: 0.8084 - val_loss: 1.5349 - val_sparse_categorical_accuracy: 0.4267
# Epoch 39/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.6301 - sparse_categorical_accuracy: 0.8231 - val_loss: 1.5312 - val_sparse_categorical_accuracy: 0.4133
# Epoch 40/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.6064 - sparse_categorical_accuracy: 0.8447 - val_loss: 1.5199 - val_sparse_categorical_accuracy: 0.4400
# Epoch 41/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.6118 - sparse_categorical_accuracy: 0.8299 - val_loss: 1.5342 - val_sparse_categorical_accuracy: 0.4400
# Epoch 42/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.5985 - sparse_categorical_accuracy: 0.8447 - val_loss: 1.5415 - val_sparse_categorical_accuracy: 0.4133
# Epoch 43/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5622 - sparse_categorical_accuracy: 0.8447 - val_loss: 1.5379 - val_sparse_categorical_accuracy: 0.4400
# Epoch 44/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5591 - sparse_categorical_accuracy: 0.8583 - val_loss: 1.5500 - val_sparse_categorical_accuracy: 0.4267
# Epoch 45/500
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.5778 - sparse_categorical_accuracy: 0.8469 - val_loss: 1.5458 - val_sparse_categorical_accuracy: 0.4533

# %%
plt.plot(history_ar.history['sparse_categorical_accuracy'])
plt.plot(history_ar.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history_ar.history['loss'])
plt.plot(history_ar.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model_ar.evaluate(test_ds)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4637 - sparse_categorical_accuracy: 0.5333
# [1.4636698961257935, 0.5333333611488342]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix


true_labels = []
predicted_labels = []

for images, labels in test_ds:
    # Get model predictions (probabilities)
    preds = model_ar.predict(images, verbose=0)
    
    # Convert to class indices
    pred_classes = np.argmax(preds, axis=1)
    
    true_labels.extend(labels.numpy())
    predicted_labels.extend(pred_classes)

true_labels      = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

class_names = test_ds.class_names 


print("Classification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_names))


cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.74      0.85      0.79        20
#        happy       0.44      0.24      0.31        17
#      neutral       0.37      0.37      0.37        19
#          sad       0.50      0.63      0.56        19
#
#     accuracy                           0.53        75
#    macro avg       0.51      0.52      0.51        75
# weighted avg       0.52      0.53      0.52        75
