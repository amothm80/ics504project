# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Only errors are logged
os.environ['TF_GPU_ALLOCATOR'] ='cuda_malloc_async'

import numpy as np
import keras
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import layers
from keras import ops

# TF imports related to tf.data preprocessing
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow.keras.utils import plot_model

keras.utils.set_random_seed(42)
from sklearn.model_selection import train_test_split
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777485321.888081  807599 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777485323.202301  807599 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
BATCH_SIZE = 32
NUM_CLASSES = 8
EPOCHS = 500
SAMPLE_RATE = 16000
OUT_SEQ_LEN = 72000

# %%
keras.backend.clear_session(free_memory=True)
train_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_stft_img/train',
image_size=(300, 300),
batch_size=BATCH_SIZE)
val_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_stft_img/val',
image_size=(300, 300),
batch_size=BATCH_SIZE)
test_ds =tf.keras.utils.image_dataset_from_directory(directory='dataset_stft_img/test',
image_size=(300, 300),
batch_size=BATCH_SIZE)
# Out:
# Found 7434 files belonging to 8 classes.
# Found 636 files belonging to 8 classes.
# Found 636 files belonging to 8 classes.

# %%
incv3 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3), pooling = 'max')
# incv3.trainable = False
model = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),

  incv3,
  layers.Dense((1024),activation='relu'),
  layers.Dense((512),activation='relu'),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model.summary()
keras.backend.clear_session(free_memory=True)
model.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 2048)           │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         4,104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,429,864 (93.19 MB)
#  Trainable params: 24,395,432 (93.06 MB)
#  Non-trainable params: 34,432 (134.50 KB)

# %%
history = model.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 116s 130ms/step - loss: 0.7579 - sparse_categorical_accuracy: 0.7238 - val_loss: 0.4467 - val_sparse_categorical_accuracy: 0.8302
# Epoch 2/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 71ms/step - loss: 0.3747 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8616
# Epoch 3/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 70ms/step - loss: 0.2318 - sparse_categorical_accuracy: 0.9168 - val_loss: 0.5291 - val_sparse_categorical_accuracy: 0.8459
# Epoch 4/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 71ms/step - loss: 0.1558 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.3874 - val_sparse_categorical_accuracy: 0.8789
# Epoch 5/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 70ms/step - loss: 0.1029 - sparse_categorical_accuracy: 0.9647 - val_loss: 0.6234 - val_sparse_categorical_accuracy: 0.8632
# Epoch 6/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 70ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9716 - val_loss: 0.4670 - val_sparse_categorical_accuracy: 0.8868
# Epoch 7/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 70ms/step - loss: 0.0781 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.4434 - val_sparse_categorical_accuracy: 0.8962
# Epoch 8/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 71ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.4372 - val_sparse_categorical_accuracy: 0.8962
# Epoch 9/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 39s 71ms/step - loss: 0.0492 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.6123 - val_sparse_categorical_accuracy: 0.8774

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model.evaluate(test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4855 - sparse_categorical_accuracy: 0.8648
# [0.4854843318462372, 0.8647798895835876]

# %%
incv3_2 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3), pooling='max')
incv3_2.trainable = False
model_2 = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),
  incv3_2,
  layers.Dropout(0.3),
  # layers.GlobalAveragePooling2D(),
  # layers.BatchNormalization(),
  layers.Dense((512),activation='relu'),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model_2.summary()
keras.backend.clear_session(free_memory=True)
model_2.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 2048)           │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         4,104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,855,976 (87.19 MB)
#  Trainable params: 1,053,192 (4.02 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
history_2 = model_2.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 25.9424 - sparse_categorical_accuracy: 0.3908 - val_loss: 6.2547 - val_sparse_categorical_accuracy: 0.6053
# Epoch 2/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 10.8377 - sparse_categorical_accuracy: 0.4759 - val_loss: 2.7339 - val_sparse_categorical_accuracy: 0.6478
# Epoch 3/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 7.1814 - sparse_categorical_accuracy: 0.4888 - val_loss: 2.4503 - val_sparse_categorical_accuracy: 0.6132
# Epoch 4/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 4.8922 - sparse_categorical_accuracy: 0.4916 - val_loss: 1.9735 - val_sparse_categorical_accuracy: 0.5613
# Epoch 5/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 2.9415 - sparse_categorical_accuracy: 0.4191 - val_loss: 1.7598 - val_sparse_categorical_accuracy: 0.3443
# Epoch 6/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.7827 - sparse_categorical_accuracy: 0.3573 - val_loss: 1.5153 - val_sparse_categorical_accuracy: 0.3947
# Epoch 7/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.6018 - sparse_categorical_accuracy: 0.3838 - val_loss: 1.3669 - val_sparse_categorical_accuracy: 0.4167
# Epoch 8/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.4909 - sparse_categorical_accuracy: 0.4158 - val_loss: 1.2748 - val_sparse_categorical_accuracy: 0.4858
# Epoch 9/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.3936 - sparse_categorical_accuracy: 0.4486 - val_loss: 1.1758 - val_sparse_categorical_accuracy: 0.5503
# Epoch 10/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.3259 - sparse_categorical_accuracy: 0.4765 - val_loss: 1.0695 - val_sparse_categorical_accuracy: 0.5692
# Epoch 11/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.2429 - sparse_categorical_accuracy: 0.5154 - val_loss: 0.9711 - val_sparse_categorical_accuracy: 0.6164
# Epoch 12/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.1907 - sparse_categorical_accuracy: 0.5365 - val_loss: 0.9509 - val_sparse_categorical_accuracy: 0.6038
# Epoch 13/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.1355 - sparse_categorical_accuracy: 0.5499 - val_loss: 0.9075 - val_sparse_categorical_accuracy: 0.6179
# Epoch 14/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.0843 - sparse_categorical_accuracy: 0.5669 - val_loss: 0.8766 - val_sparse_categorical_accuracy: 0.6447
# Epoch 15/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.0429 - sparse_categorical_accuracy: 0.5866 - val_loss: 0.8471 - val_sparse_categorical_accuracy: 0.6509
# Epoch 16/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.0210 - sparse_categorical_accuracy: 0.5944 - val_loss: 0.8096 - val_sparse_categorical_accuracy: 0.6745
# Epoch 17/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9929 - sparse_categorical_accuracy: 0.6053 - val_loss: 0.7901 - val_sparse_categorical_accuracy: 0.6808
# Epoch 18/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9700 - sparse_categorical_accuracy: 0.6171 - val_loss: 0.7648 - val_sparse_categorical_accuracy: 0.7013
# Epoch 19/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9373 - sparse_categorical_accuracy: 0.6290 - val_loss: 0.7642 - val_sparse_categorical_accuracy: 0.6824
# Epoch 20/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9263 - sparse_categorical_accuracy: 0.6349 - val_loss: 0.7591 - val_sparse_categorical_accuracy: 0.6887
# Epoch 21/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9102 - sparse_categorical_accuracy: 0.6409 - val_loss: 0.7232 - val_sparse_categorical_accuracy: 0.7170
# Epoch 22/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8887 - sparse_categorical_accuracy: 0.6506 - val_loss: 0.7188 - val_sparse_categorical_accuracy: 0.7123
# Epoch 23/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8804 - sparse_categorical_accuracy: 0.6573 - val_loss: 0.7143 - val_sparse_categorical_accuracy: 0.7264
# Epoch 24/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8694 - sparse_categorical_accuracy: 0.6602 - val_loss: 0.7009 - val_sparse_categorical_accuracy: 0.7233
# Epoch 25/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8559 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.6873 - val_sparse_categorical_accuracy: 0.7437
# Epoch 26/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8513 - sparse_categorical_accuracy: 0.6692 - val_loss: 0.7056 - val_sparse_categorical_accuracy: 0.7327
# Epoch 27/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8338 - sparse_categorical_accuracy: 0.6740 - val_loss: 0.6606 - val_sparse_categorical_accuracy: 0.7610
# Epoch 28/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8234 - sparse_categorical_accuracy: 0.6790 - val_loss: 0.6719 - val_sparse_categorical_accuracy: 0.7594
# Epoch 29/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8190 - sparse_categorical_accuracy: 0.6786 - val_loss: 0.6593 - val_sparse_categorical_accuracy: 0.7500
# Epoch 30/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8172 - sparse_categorical_accuracy: 0.6786 - val_loss: 0.6438 - val_sparse_categorical_accuracy: 0.7689
# Epoch 31/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8097 - sparse_categorical_accuracy: 0.6834 - val_loss: 0.6488 - val_sparse_categorical_accuracy: 0.7610
# Epoch 32/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8038 - sparse_categorical_accuracy: 0.6865 - val_loss: 0.6376 - val_sparse_categorical_accuracy: 0.7736
# Epoch 33/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7830 - sparse_categorical_accuracy: 0.6970 - val_loss: 0.6382 - val_sparse_categorical_accuracy: 0.7657
# Epoch 34/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7891 - sparse_categorical_accuracy: 0.6909 - val_loss: 0.6314 - val_sparse_categorical_accuracy: 0.7657
# Epoch 35/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7806 - sparse_categorical_accuracy: 0.6972 - val_loss: 0.6446 - val_sparse_categorical_accuracy: 0.7579
# Epoch 36/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7776 - sparse_categorical_accuracy: 0.6965 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.7846
# Epoch 37/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7722 - sparse_categorical_accuracy: 0.6986 - val_loss: 0.6407 - val_sparse_categorical_accuracy: 0.7610
# Epoch 38/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7669 - sparse_categorical_accuracy: 0.7013 - val_loss: 0.6120 - val_sparse_categorical_accuracy: 0.7720
# Epoch 39/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7536 - sparse_categorical_accuracy: 0.7077 - val_loss: 0.6105 - val_sparse_categorical_accuracy: 0.7783
# Epoch 40/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7604 - sparse_categorical_accuracy: 0.7055 - val_loss: 0.6213 - val_sparse_categorical_accuracy: 0.7767
# Epoch 41/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7533 - sparse_categorical_accuracy: 0.7066 - val_loss: 0.6092 - val_sparse_categorical_accuracy: 0.7862
# Epoch 42/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7452 - sparse_categorical_accuracy: 0.7113 - val_loss: 0.5924 - val_sparse_categorical_accuracy: 0.7862
# Epoch 43/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7488 - sparse_categorical_accuracy: 0.7096 - val_loss: 0.5937 - val_sparse_categorical_accuracy: 0.7846
# Epoch 44/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7391 - sparse_categorical_accuracy: 0.7099 - val_loss: 0.5901 - val_sparse_categorical_accuracy: 0.7846
# Epoch 45/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7369 - sparse_categorical_accuracy: 0.7156 - val_loss: 0.5860 - val_sparse_categorical_accuracy: 0.7925
# Epoch 46/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7306 - sparse_categorical_accuracy: 0.7166 - val_loss: 0.6081 - val_sparse_categorical_accuracy: 0.7752
# Epoch 47/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7356 - sparse_categorical_accuracy: 0.7146 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.7736
# Epoch 48/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7268 - sparse_categorical_accuracy: 0.7169 - val_loss: 0.5745 - val_sparse_categorical_accuracy: 0.7972
# Epoch 49/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7301 - sparse_categorical_accuracy: 0.7171 - val_loss: 0.5871 - val_sparse_categorical_accuracy: 0.7877
# Epoch 50/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7203 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5821 - val_sparse_categorical_accuracy: 0.7925
# Epoch 51/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7257 - sparse_categorical_accuracy: 0.7160 - val_loss: 0.5813 - val_sparse_categorical_accuracy: 0.7956
# Epoch 52/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7108 - sparse_categorical_accuracy: 0.7218 - val_loss: 0.5845 - val_sparse_categorical_accuracy: 0.7862
# Epoch 53/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7136 - sparse_categorical_accuracy: 0.7216 - val_loss: 0.5916 - val_sparse_categorical_accuracy: 0.7862

# %%
plt.plot(history_2.history['sparse_categorical_accuracy'])
plt.plot(history_2.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model_2.evaluate(test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6318 - sparse_categorical_accuracy: 0.7689
# [0.6318353414535522, 0.7688679099082947]

# %%
incv3_3 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3))
incv3_3.trainable = False
model_3 = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),
  incv3_3,
  layers.GlobalAveragePooling2D(),
  layers.BatchNormalization(),
  layers.Dense((128),activation='relu'),
  layers.Dropout(0.3),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model_3.summary()
keras.backend.clear_session(free_memory=True)
model_3.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,074,280 (84.21 MB)
#  Trainable params: 267,400 (1.02 MB)
#  Non-trainable params: 21,806,880 (83.19 MB)

# %%
history_3 = model_3.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - loss: 1.2947 - sparse_categorical_accuracy: 0.5318 - val_loss: 0.7996 - val_sparse_categorical_accuracy: 0.7138
# Epoch 2/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9142 - sparse_categorical_accuracy: 0.6663 - val_loss: 0.6957 - val_sparse_categorical_accuracy: 0.7406
# Epoch 3/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8028 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.6436 - val_sparse_categorical_accuracy: 0.7516
# Epoch 4/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7530 - sparse_categorical_accuracy: 0.7183 - val_loss: 0.6056 - val_sparse_categorical_accuracy: 0.7783
# Epoch 5/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7068 - sparse_categorical_accuracy: 0.7337 - val_loss: 0.5877 - val_sparse_categorical_accuracy: 0.7814
# Epoch 6/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.7506 - val_loss: 0.5722 - val_sparse_categorical_accuracy: 0.7893
# Epoch 7/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6530 - sparse_categorical_accuracy: 0.7544 - val_loss: 0.5496 - val_sparse_categorical_accuracy: 0.8066
# Epoch 8/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6216 - sparse_categorical_accuracy: 0.7677 - val_loss: 0.5426 - val_sparse_categorical_accuracy: 0.7972
# Epoch 9/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6030 - sparse_categorical_accuracy: 0.7750 - val_loss: 0.5463 - val_sparse_categorical_accuracy: 0.8082
# Epoch 10/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5817 - sparse_categorical_accuracy: 0.7834 - val_loss: 0.5358 - val_sparse_categorical_accuracy: 0.8003
# Epoch 11/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5679 - sparse_categorical_accuracy: 0.7891 - val_loss: 0.5264 - val_sparse_categorical_accuracy: 0.8097
# Epoch 12/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5542 - sparse_categorical_accuracy: 0.7950 - val_loss: 0.5335 - val_sparse_categorical_accuracy: 0.8050
# Epoch 13/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5369 - sparse_categorical_accuracy: 0.8018 - val_loss: 0.5302 - val_sparse_categorical_accuracy: 0.8066
# Epoch 14/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5281 - sparse_categorical_accuracy: 0.8051 - val_loss: 0.5284 - val_sparse_categorical_accuracy: 0.8082
# Epoch 15/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5067 - sparse_categorical_accuracy: 0.8129 - val_loss: 0.5331 - val_sparse_categorical_accuracy: 0.8050
# Epoch 16/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4965 - sparse_categorical_accuracy: 0.8169 - val_loss: 0.5193 - val_sparse_categorical_accuracy: 0.8145
# Epoch 17/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4894 - sparse_categorical_accuracy: 0.8189 - val_loss: 0.5174 - val_sparse_categorical_accuracy: 0.8176
# Epoch 18/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4829 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.5278 - val_sparse_categorical_accuracy: 0.8082
# Epoch 19/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4676 - sparse_categorical_accuracy: 0.8300 - val_loss: 0.5200 - val_sparse_categorical_accuracy: 0.8145
# Epoch 20/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4621 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.5291 - val_sparse_categorical_accuracy: 0.8097
# Epoch 21/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4518 - sparse_categorical_accuracy: 0.8347 - val_loss: 0.5266 - val_sparse_categorical_accuracy: 0.8129
# Epoch 22/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4374 - sparse_categorical_accuracy: 0.8397 - val_loss: 0.5308 - val_sparse_categorical_accuracy: 0.8129

# %%
plt.plot(history_3.history['sparse_categorical_accuracy'])
plt.plot(history_3.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model_3.evaluate(test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.8066
# [0.5410348773002625, 0.8066037893295288]

# %%
incv3_4 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3))
incv3_4.trainable = False
# for layer in incv3_4.layers[-50:]:
#     layer.trainable = True
model_4 = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),
  layers.Rescaling(1./127.5, offset=-1),
  incv3_4,
  layers.GlobalAveragePooling2D(),
  layers.BatchNormalization(),
  layers.Dense((128),activation='relu'),
  layers.Dropout(0.3),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model_4.summary()
keras.backend.clear_session(free_memory=True)
model_4.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-5),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,074,280 (84.21 MB)
#  Trainable params: 267,400 (1.02 MB)
#  Non-trainable params: 21,806,880 (83.19 MB)

# %%
history_4 = model_4.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - loss: 2.1145 - sparse_categorical_accuracy: 0.2747 - val_loss: 1.4390 - val_sparse_categorical_accuracy: 0.4764
# Epoch 2/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.5521 - sparse_categorical_accuracy: 0.4456 - val_loss: 1.1826 - val_sparse_categorical_accuracy: 0.5723
# Epoch 3/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.3446 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.0533 - val_sparse_categorical_accuracy: 0.6164
# Epoch 4/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.2275 - sparse_categorical_accuracy: 0.5599 - val_loss: 0.9713 - val_sparse_categorical_accuracy: 0.6384
# Epoch 5/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.1423 - sparse_categorical_accuracy: 0.5840 - val_loss: 0.9109 - val_sparse_categorical_accuracy: 0.6619
# Epoch 6/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.0745 - sparse_categorical_accuracy: 0.6108 - val_loss: 0.8679 - val_sparse_categorical_accuracy: 0.6808
# Epoch 7/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 1.0132 - sparse_categorical_accuracy: 0.6311 - val_loss: 0.8318 - val_sparse_categorical_accuracy: 0.6950
# Epoch 8/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9724 - sparse_categorical_accuracy: 0.6452 - val_loss: 0.8048 - val_sparse_categorical_accuracy: 0.7013
# Epoch 9/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9426 - sparse_categorical_accuracy: 0.6553 - val_loss: 0.7822 - val_sparse_categorical_accuracy: 0.7154
# Epoch 10/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.9084 - sparse_categorical_accuracy: 0.6701 - val_loss: 0.7614 - val_sparse_categorical_accuracy: 0.7201
# Epoch 11/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8688 - sparse_categorical_accuracy: 0.6824 - val_loss: 0.7433 - val_sparse_categorical_accuracy: 0.7201
# Epoch 12/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8568 - sparse_categorical_accuracy: 0.6859 - val_loss: 0.7238 - val_sparse_categorical_accuracy: 0.7343
# Epoch 13/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8329 - sparse_categorical_accuracy: 0.6926 - val_loss: 0.7125 - val_sparse_categorical_accuracy: 0.7343
# Epoch 14/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.8168 - sparse_categorical_accuracy: 0.7040 - val_loss: 0.7010 - val_sparse_categorical_accuracy: 0.7469
# Epoch 15/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7947 - sparse_categorical_accuracy: 0.7088 - val_loss: 0.6910 - val_sparse_categorical_accuracy: 0.7421
# Epoch 16/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7818 - sparse_categorical_accuracy: 0.7138 - val_loss: 0.6840 - val_sparse_categorical_accuracy: 0.7484
# Epoch 17/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7616 - sparse_categorical_accuracy: 0.7164 - val_loss: 0.6754 - val_sparse_categorical_accuracy: 0.7531
# Epoch 18/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7483 - sparse_categorical_accuracy: 0.7285 - val_loss: 0.6678 - val_sparse_categorical_accuracy: 0.7516
# Epoch 19/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7364 - sparse_categorical_accuracy: 0.7282 - val_loss: 0.6602 - val_sparse_categorical_accuracy: 0.7626
# Epoch 20/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7255 - sparse_categorical_accuracy: 0.7323 - val_loss: 0.6539 - val_sparse_categorical_accuracy: 0.7642
# Epoch 21/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7146 - sparse_categorical_accuracy: 0.7371 - val_loss: 0.6468 - val_sparse_categorical_accuracy: 0.7673
# Epoch 22/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.7025 - sparse_categorical_accuracy: 0.7404 - val_loss: 0.6417 - val_sparse_categorical_accuracy: 0.7704
# Epoch 23/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6911 - sparse_categorical_accuracy: 0.7474 - val_loss: 0.6365 - val_sparse_categorical_accuracy: 0.7720
# Epoch 24/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6847 - sparse_categorical_accuracy: 0.7508 - val_loss: 0.6321 - val_sparse_categorical_accuracy: 0.7704
# Epoch 25/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6756 - sparse_categorical_accuracy: 0.7518 - val_loss: 0.6280 - val_sparse_categorical_accuracy: 0.7736
# Epoch 26/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6658 - sparse_categorical_accuracy: 0.7567 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.7862
# Epoch 27/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6610 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.6192 - val_sparse_categorical_accuracy: 0.7783
# Epoch 28/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6530 - sparse_categorical_accuracy: 0.7578 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.7846
# Epoch 29/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6420 - sparse_categorical_accuracy: 0.7625 - val_loss: 0.6119 - val_sparse_categorical_accuracy: 0.7830
# Epoch 30/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6382 - sparse_categorical_accuracy: 0.7647 - val_loss: 0.6106 - val_sparse_categorical_accuracy: 0.7846
# Epoch 31/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6277 - sparse_categorical_accuracy: 0.7697 - val_loss: 0.6087 - val_sparse_categorical_accuracy: 0.7909
# Epoch 32/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6200 - sparse_categorical_accuracy: 0.7751 - val_loss: 0.6046 - val_sparse_categorical_accuracy: 0.7972
# Epoch 33/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6178 - sparse_categorical_accuracy: 0.7723 - val_loss: 0.6017 - val_sparse_categorical_accuracy: 0.7925
# Epoch 34/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6089 - sparse_categorical_accuracy: 0.7763 - val_loss: 0.5991 - val_sparse_categorical_accuracy: 0.7972
# Epoch 35/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.6071 - sparse_categorical_accuracy: 0.7784 - val_loss: 0.5986 - val_sparse_categorical_accuracy: 0.7972
# Epoch 36/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5938 - sparse_categorical_accuracy: 0.7821 - val_loss: 0.5956 - val_sparse_categorical_accuracy: 0.7987
# Epoch 37/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5899 - sparse_categorical_accuracy: 0.7843 - val_loss: 0.5946 - val_sparse_categorical_accuracy: 0.7972
# Epoch 38/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5873 - sparse_categorical_accuracy: 0.7880 - val_loss: 0.5914 - val_sparse_categorical_accuracy: 0.7987
# Epoch 39/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5821 - sparse_categorical_accuracy: 0.7894 - val_loss: 0.5903 - val_sparse_categorical_accuracy: 0.7972
# Epoch 40/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5727 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5873 - val_sparse_categorical_accuracy: 0.7940
# Epoch 41/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5692 - sparse_categorical_accuracy: 0.7929 - val_loss: 0.5863 - val_sparse_categorical_accuracy: 0.7956
# Epoch 42/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5729 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.5835 - val_sparse_categorical_accuracy: 0.7940
# Epoch 43/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.5587 - sparse_categorical_accuracy: 0.8003 - val_loss: 0.5845 - val_sparse_categorical_accuracy: 0.7956
# Epoch 44/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5585 - sparse_categorical_accuracy: 0.8007 - val_loss: 0.5822 - val_sparse_categorical_accuracy: 0.7987
# Epoch 45/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5500 - sparse_categorical_accuracy: 0.8013 - val_loss: 0.5818 - val_sparse_categorical_accuracy: 0.7956
# Epoch 46/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5495 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.5798 - val_sparse_categorical_accuracy: 0.7956
# Epoch 47/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5437 - sparse_categorical_accuracy: 0.8028 - val_loss: 0.5782 - val_sparse_categorical_accuracy: 0.7925
# Epoch 48/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5381 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.5765 - val_sparse_categorical_accuracy: 0.7940
# Epoch 49/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5334 - sparse_categorical_accuracy: 0.8086 - val_loss: 0.5754 - val_sparse_categorical_accuracy: 0.7972
# Epoch 50/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5262 - sparse_categorical_accuracy: 0.8136 - val_loss: 0.5732 - val_sparse_categorical_accuracy: 0.8019
# Epoch 51/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5273 - sparse_categorical_accuracy: 0.8097 - val_loss: 0.5723 - val_sparse_categorical_accuracy: 0.7987
# Epoch 52/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5186 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.5708 - val_sparse_categorical_accuracy: 0.8003
# Epoch 53/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5188 - sparse_categorical_accuracy: 0.8153 - val_loss: 0.5701 - val_sparse_categorical_accuracy: 0.7987
# Epoch 54/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5169 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.5693 - val_sparse_categorical_accuracy: 0.8019
# Epoch 55/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5081 - sparse_categorical_accuracy: 0.8191 - val_loss: 0.5683 - val_sparse_categorical_accuracy: 0.7956
# Epoch 56/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.5066 - sparse_categorical_accuracy: 0.8186 - val_loss: 0.5671 - val_sparse_categorical_accuracy: 0.8019
# Epoch 57/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.5010 - sparse_categorical_accuracy: 0.8226 - val_loss: 0.5678 - val_sparse_categorical_accuracy: 0.8050
# Epoch 58/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4980 - sparse_categorical_accuracy: 0.8223 - val_loss: 0.5662 - val_sparse_categorical_accuracy: 0.8035
# Epoch 59/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4980 - sparse_categorical_accuracy: 0.8213 - val_loss: 0.5655 - val_sparse_categorical_accuracy: 0.8019
# Epoch 60/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4870 - sparse_categorical_accuracy: 0.8267 - val_loss: 0.5641 - val_sparse_categorical_accuracy: 0.8035
# Epoch 61/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4898 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.5645 - val_sparse_categorical_accuracy: 0.8019
# Epoch 62/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4822 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.5635 - val_sparse_categorical_accuracy: 0.8035
# Epoch 63/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4788 - sparse_categorical_accuracy: 0.8299 - val_loss: 0.5619 - val_sparse_categorical_accuracy: 0.8019
# Epoch 64/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4716 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.5619 - val_sparse_categorical_accuracy: 0.8019
# Epoch 65/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4694 - sparse_categorical_accuracy: 0.8347 - val_loss: 0.5613 - val_sparse_categorical_accuracy: 0.8019
# Epoch 66/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4743 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.5611 - val_sparse_categorical_accuracy: 0.8050
# Epoch 67/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4667 - sparse_categorical_accuracy: 0.8368 - val_loss: 0.5617 - val_sparse_categorical_accuracy: 0.8066
# Epoch 68/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4653 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.5590 - val_sparse_categorical_accuracy: 0.8035
# Epoch 69/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4569 - sparse_categorical_accuracy: 0.8405 - val_loss: 0.5587 - val_sparse_categorical_accuracy: 0.8003
# Epoch 70/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4606 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.5580 - val_sparse_categorical_accuracy: 0.8082
# Epoch 71/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4592 - sparse_categorical_accuracy: 0.8361 - val_loss: 0.5580 - val_sparse_categorical_accuracy: 0.8050
# Epoch 72/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4502 - sparse_categorical_accuracy: 0.8403 - val_loss: 0.5577 - val_sparse_categorical_accuracy: 0.8050
# Epoch 73/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4520 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.5582 - val_sparse_categorical_accuracy: 0.8035
# Epoch 74/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4454 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.5573 - val_sparse_categorical_accuracy: 0.8035
# Epoch 75/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.5567 - val_sparse_categorical_accuracy: 0.8035
# Epoch 76/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4361 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.5572 - val_sparse_categorical_accuracy: 0.8035
# Epoch 77/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4352 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.5551 - val_sparse_categorical_accuracy: 0.8035
# Epoch 78/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4290 - sparse_categorical_accuracy: 0.8475 - val_loss: 0.5559 - val_sparse_categorical_accuracy: 0.8003
# Epoch 79/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4295 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.5566 - val_sparse_categorical_accuracy: 0.8035
# Epoch 80/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4262 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.5557 - val_sparse_categorical_accuracy: 0.8050
# Epoch 81/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4246 - sparse_categorical_accuracy: 0.8501 - val_loss: 0.5574 - val_sparse_categorical_accuracy: 0.8019
# Epoch 82/500
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.4208 - sparse_categorical_accuracy: 0.8525 - val_loss: 0.5559 - val_sparse_categorical_accuracy: 0.8019

# %%
plt.plot(history_4.history['sparse_categorical_accuracy'])
plt.plot(history_4.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model_4.evaluate(test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5068 - sparse_categorical_accuracy: 0.8019
# [0.5068264603614807, 0.801886796951294]

# %%
incv3_5 = keras.applications.InceptionV3(include_top=False,input_shape=(300,300,3))
incv3_5.trainable = False
for layer in incv3_5.layers[-20:]:
    layer.trainable = True
model_5 = keras.Sequential([
  layers.Input(shape=(300,300,3),name='input'),
  layers.Rescaling(1./127.5, offset=-1),
  incv3_5,
  layers.GlobalAveragePooling2D(),
  layers.BatchNormalization(),
  layers.Dense((128),activation='gelu',
                   kernel_regularizer=keras.regularizers.L1L2(l1=1e-5, l2=1e-4),

               ),
  layers.Dropout(0.4),
  layers.Dense((NUM_CLASSES),activation = 'softmax',name='output')
])
model_5.summary()
keras.backend.clear_session(free_memory=True)
model_5.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-5,weight_decay=1e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_94          │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,074,280 (84.21 MB)
#  Trainable params: 2,202,760 (8.40 MB)
#  Non-trainable params: 19,871,520 (75.80 MB)

# %%
history_5 = model_5.fit(train_ds,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
          validation_data=val_ds,
        callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True,
        )]        )
# Out:
# Epoch 1/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 44s 118ms/step - loss: 2.1293 - sparse_categorical_accuracy: 0.3134 - val_loss: 1.3219 - val_sparse_categorical_accuracy: 0.6085
# Epoch 2/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 1.4544 - sparse_categorical_accuracy: 0.5153 - val_loss: 0.9649 - val_sparse_categorical_accuracy: 0.7013
# Epoch 3/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 1.2052 - sparse_categorical_accuracy: 0.6065 - val_loss: 0.8449 - val_sparse_categorical_accuracy: 0.7374
# Epoch 4/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 1.0771 - sparse_categorical_accuracy: 0.6486 - val_loss: 0.7830 - val_sparse_categorical_accuracy: 0.7594
# Epoch 5/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.9846 - sparse_categorical_accuracy: 0.6827 - val_loss: 0.7408 - val_sparse_categorical_accuracy: 0.7752
# Epoch 6/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.9089 - sparse_categorical_accuracy: 0.7116 - val_loss: 0.7129 - val_sparse_categorical_accuracy: 0.7767
# Epoch 7/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.8575 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.6885 - val_sparse_categorical_accuracy: 0.7862
# Epoch 8/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.7983 - sparse_categorical_accuracy: 0.7498 - val_loss: 0.6705 - val_sparse_categorical_accuracy: 0.7925
# Epoch 9/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.7591 - sparse_categorical_accuracy: 0.7616 - val_loss: 0.6567 - val_sparse_categorical_accuracy: 0.7940
# Epoch 10/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.7198 - sparse_categorical_accuracy: 0.7776 - val_loss: 0.6448 - val_sparse_categorical_accuracy: 0.7909
# Epoch 11/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.6974 - sparse_categorical_accuracy: 0.7848 - val_loss: 0.6319 - val_sparse_categorical_accuracy: 0.8035
# Epoch 12/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.6442 - sparse_categorical_accuracy: 0.8064 - val_loss: 0.6226 - val_sparse_categorical_accuracy: 0.8003
# Epoch 13/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.6235 - sparse_categorical_accuracy: 0.8113 - val_loss: 0.6131 - val_sparse_categorical_accuracy: 0.8003
# Epoch 14/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.6149 - sparse_categorical_accuracy: 0.8210 - val_loss: 0.6083 - val_sparse_categorical_accuracy: 0.8097
# Epoch 15/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.5811 - sparse_categorical_accuracy: 0.8315 - val_loss: 0.6033 - val_sparse_categorical_accuracy: 0.8113
# Epoch 16/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.5551 - sparse_categorical_accuracy: 0.8403 - val_loss: 0.5976 - val_sparse_categorical_accuracy: 0.8129
# Epoch 17/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.5307 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.5882 - val_sparse_categorical_accuracy: 0.8145
# Epoch 18/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.5193 - sparse_categorical_accuracy: 0.8602 - val_loss: 0.5869 - val_sparse_categorical_accuracy: 0.8192
# Epoch 19/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8676 - val_loss: 0.5792 - val_sparse_categorical_accuracy: 0.8176
# Epoch 20/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.4687 - sparse_categorical_accuracy: 0.8805 - val_loss: 0.5719 - val_sparse_categorical_accuracy: 0.8176
# Epoch 21/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.4605 - sparse_categorical_accuracy: 0.8830 - val_loss: 0.5693 - val_sparse_categorical_accuracy: 0.8302
# Epoch 22/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.4318 - sparse_categorical_accuracy: 0.8935 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.8333
# Epoch 23/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.4223 - sparse_categorical_accuracy: 0.8974 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.8270
# Epoch 24/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.4161 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.5561 - val_sparse_categorical_accuracy: 0.8302
# Epoch 25/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.3978 - sparse_categorical_accuracy: 0.9049 - val_loss: 0.5534 - val_sparse_categorical_accuracy: 0.8396
# Epoch 26/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.3827 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.5498 - val_sparse_categorical_accuracy: 0.8412
# Epoch 27/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.3719 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.8412
# Epoch 28/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.3552 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.5506 - val_sparse_categorical_accuracy: 0.8396
# Epoch 29/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.3448 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.5466 - val_sparse_categorical_accuracy: 0.8428
# Epoch 30/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.3320 - sparse_categorical_accuracy: 0.9322 - val_loss: 0.5493 - val_sparse_categorical_accuracy: 0.8365
# Epoch 31/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.3317 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.5428 - val_sparse_categorical_accuracy: 0.8475
# Epoch 32/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.3115 - sparse_categorical_accuracy: 0.9408 - val_loss: 0.5456 - val_sparse_categorical_accuracy: 0.8302
# Epoch 33/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.3017 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.5468 - val_sparse_categorical_accuracy: 0.8286
# Epoch 34/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.5417 - val_sparse_categorical_accuracy: 0.8333
# Epoch 35/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.2836 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.5429 - val_sparse_categorical_accuracy: 0.8349
# Epoch 36/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.2772 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.5344 - val_sparse_categorical_accuracy: 0.8428
# Epoch 37/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.2644 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.5367 - val_sparse_categorical_accuracy: 0.8443
# Epoch 38/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.5399 - val_sparse_categorical_accuracy: 0.8443
# Epoch 39/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.2553 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.5387 - val_sparse_categorical_accuracy: 0.8396
# Epoch 40/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.2517 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.5346 - val_sparse_categorical_accuracy: 0.8443
# Epoch 41/500
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.2376 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.5345 - val_sparse_categorical_accuracy: 0.8491

# %%
plt.plot(history_5.history['sparse_categorical_accuracy'])
plt.plot(history_5.history['val_sparse_categorical_accuracy'],linestyle='--')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'],linestyle='--')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
model5_pred = model_5.evaluate(test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5129 - sparse_categorical_accuracy: 0.8428

# %%
model_5.save('stft_model.keras')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix


true_labels = []
predicted_labels = []

for images, labels in test_ds:
    # Get model predictions (probabilities)
    preds = model_5.predict(images, verbose=0)
    
    # Convert to class indices
    pred_classes = np.argmax(preds, axis=1)
    
    true_labels.extend(labels.numpy())
    predicted_labels.extend(pred_classes)

true_labels      = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

class_names = test_ds.class_names 


print("Classification Report:")
print(classification_report(true_labels, predicted_labels, target_names=class_names))


cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.93      0.91      0.92        88
#         calm       0.60      0.83      0.70        29
#      disgust       0.85      0.87      0.86        89
#         fear       0.83      0.85      0.84        89
#        happy       0.81      0.83      0.82        89
#      neutral       0.93      0.86      0.90        74
#          sad       0.84      0.72      0.78        89
#    surprised       0.85      0.87      0.86        89
#
#     accuracy                           0.84       636
#    macro avg       0.83      0.84      0.83       636
# weighted avg       0.85      0.84      0.84       636
