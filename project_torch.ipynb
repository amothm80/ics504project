# %%
import torch
import torchaudio

# Define the path to your audio file (e.g., .wav, .mp3)
audio_file_path = "/home/ahmed/workspace/kfupm/ics504/project/datasets/surprised/03-01-08-01-01-01-01.wav"

# Load the audio data
waveform, sample_rate = torchaudio.load(audio_file_path)

# Print the results
print(f"Waveform shape: {waveform.shape}")
print(f"Sample rate: {sample_rate} Hz")
print(f"Waveform dtype: {waveform.dtype}")
print(f"Waveform value range: [{waveform.min()}, {waveform.max()}]")
# Out:
# Waveform shape: torch.Size([1, 163363])
# Sample rate: 48000 Hz
# Waveform dtype: torch.float32
# Waveform value range: [-0.063446044921875, 0.06622314453125]
